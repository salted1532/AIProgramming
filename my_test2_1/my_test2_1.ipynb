# %%
# 음성인식
# 
# 
# https://github.com/openai/whisper

# %%
# cli에서 설치

# 1) ffmpeg 설치
#sudo apt update && sudo apt install ffmpeg

# 2) openai-whsiper 설치
#pip install git+https://github.com/openai/whisper.git

# %%
# !pip install ffmpeg-python
# Out:
# Collecting ffmpeg-python
#   Downloading ffmpeg_python-0.2.0-py3-none-any.whl.metadata (1.7 kB)
# Collecting future (from ffmpeg-python)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Downloading ffmpeg_python-0.2.0-py3-none-any.whl (25 kB)
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Installing collected packages: future, ffmpeg-python
# Successfully installed ffmpeg-python-0.2.0 future-1.0.0

# %%
# !pip install git+https://github.com/openai/whisper.git
# Out:
# Collecting git+https://github.com/openai/whisper.git
#   Cloning https://github.com/openai/whisper.git to /tmp/pip-req-build-q2_5niuh
#   Running command git clone --filter=blob:none --quiet https://github.com/openai/whisper.git /tmp/pip-req-build-q2_5niuh
#   Resolved https://github.com/openai/whisper.git to commit 423492dda7806206abe56bdfe427c1096473a020
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numba in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from openai-whisper==20240927) (0.60.0)
# Requirement already satisfied: numpy in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from openai-whisper==20240927) (1.26.4)
# Requirement already satisfied: torch in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from openai-whisper==20240927) (2.4.1)
# Requirement already satisfied: tqdm in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from openai-whisper==20240927) (4.66.5)
# Requirement already satisfied: more-itertools in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from openai-whisper==20240927) (10.5.0)
# Requirement already satisfied: tiktoken in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from openai-whisper==20240927) (0.7.0)
# Requirement already satisfied: triton>=2.0.0 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from openai-whisper==20240927) (3.0.0)
# Requirement already satisfied: filelock in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from triton>=2.0.0->openai-whisper==20240927) (3.15.4)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from numba->openai-whisper==20240927) (0.43.0)
# Requirement already satisfied: regex>=2022.1.18 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from tiktoken->openai-whisper==20240927) (2024.7.24)
# Requirement already satisfied: requests>=2.26.0 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from tiktoken->openai-whisper==20240927) (2.32.3)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (4.12.2)
# Requirement already satisfied: sympy in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (1.13.2)
# Requirement already satisfied: networkx in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (3.2.1)
# Requirement already satisfied: jinja2 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (3.1.4)
# Requirement already satisfied: fsspec in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (2024.9.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.20.5 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (2.20.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from torch->openai-whisper==20240927) (12.1.105)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch->openai-whisper==20240927) (12.6.68)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240927) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240927) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240927) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken->openai-whisper==20240927) (2024.8.30)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from jinja2->torch->openai-whisper==20240927) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages (from sympy->torch->openai-whisper==20240927) (1.3.0)
# Building wheels for collected packages: openai-whisper
#   Building wheel for openai-whisper (pyproject.toml) ... done
#   Created wheel for openai-whisper: filename=openai_whisper-20240927-py3-none-any.whl size=802818 sha256=90265e55b3e92f7684abf4d56686d0a47686e53c2c663956f4c0628761bc3db1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-hqvw0foo/wheels/fe/03/29/e7919208d11b4ab32972cb448bb84a9a675d92cd52c9a48341
# Successfully built openai-whisper
# Installing collected packages: openai-whisper
#   Attempting uninstall: openai-whisper
#     Found existing installation: openai-whisper 20231117
#     Uninstalling openai-whisper-20231117:
#       Successfully uninstalled openai-whisper-20231117
# Successfully installed openai-whisper-20240927

# %%
import whisper

model = whisper.load_model("base")
result = model.transcribe("[경제PICK] 이제는 광고의 시간...올림픽 스타 마케팅  YTN.mp3")
print(result["text"])
# Out:
# /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages/whisper/__init__.py:146: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# /home/mhkwon/anaconda3/envs/my_env/lib/python3.9/site-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  이제 이제는 광고의 시간 우리 픽 스타트 마케팅. 광고 시작했더라고요. 시나비 선수도 했고. 누구 제일 좀 관심 가지고 보셨습니까? 시나비가 왔죠. 너무 귀엽잖아요. 너무 귀엽고. 특히 이제 먹방이 굉장히 좀 이슈가 됐을 거네요. 저도 이렇게 일하다 보면 이렇게 안에 와서 반환을 계속 먹여서 그런 것도 있었습니다. 자, 경기 중간중간 이렇게 뭐 반환하도 먹었고 주목받고 이게 또 다른 재미라고도 얘기했고 당시 누리꾼들이 광고조라 이런 댓글 응원을 참 안 하는데 이게 현실로 일어졌습니다. GS 리테일이 운영하는 편의점, GS25. 신유빈과 희벅판 주목받 또 소용량 반찬 제품을 선거하고 있습니다. 또 빙그레는요. 제발 16개를 이미 바단함하시나 우유의 우유의 모델로 신유빈 선수를 발탑했습니다. 빙그레는 올리필 패막 직후에 신유빈 선수와 광고 모델 계약에 체결했고요. 이른실래의 영상광고 등을 촬영해서 공개할 예정입니다. 그런데 신선수 빙그레 광고 모델 이로건을 기부를 하기로 했습니다. 그래서 한국 초등학교 탁구 연낭에 기부를 해서 한국 탁구 발전을 위해서 함께 하겠다 이런 이야기했습니다. 맘도 차함 따뜻하고 이것뿐만 아니라 납작 복숭아 좀 먹었는데 이것도 쓱타콤해서 사전 이야기를 했는데 완판, 500개가판 됐다고 하는데요. 좋은 일도 하고 참고했습니다. 맞습니다. 제가 신유빈 선수와 직접 통화를 해보고 싶었어요. 어떻게 생각하는지 근데 지금 휴가중이라고 합니다. 그래서 지금 매니저도 연락할 수가 없는 상황이었고 그래서 그냥 제가 문자로만 이야기를 받았는데 이렇게 얘기했습니다. 많은 사랑을 받아서 너무 감사하다. 광고 모델로 경험할 수 있는 기회를 그것때면 어딘 것 같고 다시 한번 응원해주신 분들에게 감사하고 앞으로 좋은 모습 보여드릴 수 있도록 노력하는 선수가 되겠다 이렇게 문자를 받았습니다. 신유빈 선수 외에도 올림픽스타들이 광고의 모습을 드러내고 있잖아요. 맞습니다. 조금 전에 그 영상에도 나왔는데 맥주 회사에서는 팬싱사부로 국가대표, 오사홍선수, 훗남, 너무 좋아하신 것 같은데 근무해다 소식을 할래 오사홍선수. 한국 선수로 최초로 개인전 커력 그리는 설렘을 달성했죠. 그러다 보니까 여러 관심을 받았고 또 외모로도 가실을 받았습니다. 오빈 맥주가 인스타그램을 통해서 오사홍선수가 모델을 했으면 알렸고요. 앞으로 이제 어떻게 활동하는지 천천히 밝힌다고 했습니다. 그런데 올림픽스타들을 왜 원하는지 전문가 입장해서 좀 들어봤습니다. 그래요? 함께 해봅시다. 네. 네. 네. 이번 올림픽에서 매달을 획득한 선수들의 경우에는 각종 예능에도 출연하고 있고 이미 대중적인 인지도와 관심을 받고 있기 때문에 각 기업들은 그런 부분들을 고려한 것이 아닌가 싶습니다. 그래서 올림픽 기간 동안 획득된 스포츠스타에 어떤 인지도를 바탕으로 해서 당기적인 제품이나 서비스의 인지도를 높이기 위한 전략인 것으로 해석할 수 있을 것 같습니다. 한동안이 전략이 계속될 것으로 보이죠. 신유비는 오사홍선수 외에도요. 사격의 김예지 선수. 김예지 선수는 어떤 브랜드 관골을 맡았나요? 명품이라고만 밝혔습니다. 명품 브랜드에서 화보 촬영을 하게 됐고요. 그리고 소속사가 생겼어요. 소속사 측의 문의를 하고니까 앞으로 한 20개 정도 예정이 되어있다 이렇게 인터뷰를 한 것으로 나오고 있는데 자세한 건 나오진 않았습니다. 그리고 일단은 예지 선수가 현재 건강을 완전히 회복한 상태고 현재는 대회에 집중만 하겠다. 이렇게 밝은 상황이에요. 그러다 보니까 앞으로 저희들이 관골을 통해서 어떻게 나온지 좀 보면 될 것 같고. 이번에 저희가 예상 외로 참 좋은 성적을 거섰기 때문에 더 이미지가 좋은 부분이 있는 것 같아요. 그러다 보니까 기업 측에서도 더 많은 선수들을 활용하지 않을까. 이제 관고의 시간이다. 이거 좀 기다려가지고 뽑아봤습니다. 잘 들었습니다. 반가운 소식이었고요. 또 관골도 찍고 좋은 일도 한다는 게 더 좋습니다. 잘 들었습니다. 오동원 기절 함께 했습니다. 고맙습니다. 고맙습니다.

# %%
result
# Out:
# {'text': ' 다음 extension 이제는 광고의 시간 우리 오리픽 스타들 마케팅. 광고 시작했더라고요. 시럽에서 지도 했고. 누구 제일 좀 관심 가지고 보셨습니까? 시럽에서 지도. 너무 귀엽잖아요. 너무 귀엽고. 특히 이제 먹방이 굉장히 좀 이슈가 됐을 거네요. 저도 이렇게 일하다 보면 이렇게 안에 와서 바다 하나 계속 먹여서 그런 것도 있었습니다. 자, 경기 중간중간 이렇게 뭐 바다나도 먹었고 주목받고 이게 또 다른 재미이라고도 또 얘기했고 당시 누리꾼들이 광고조라 이런 댓글 응원을 참 안 하는데 이게 현실로 일어졌습니다. GS 리테일이 운영하는 편의점 GS25 시뉘빙과 희벅판 주목받 또 소용량 반찬 제품을 선거하고 했습니다. 또 빙그레는요. 제날 16일에 이미 바다나마신한 우유의 모유의 모델로 시뉘빙 선수를 발탑을 했습니다. 빙그레는 오리픽 패막 직후에 시뉘빙 선수와 광고 모델 계약에 체결했고요. 이랬실에 영상광고 등을 촬영해서 공개할 예정입니다. 그런데 신선수 빙그레 광고 모델 이로건을 기부를 하기로 했습니다. 마음도 예뻐요. 한국 초등학교 타고 연낭에 기부를 해서 한국 타고 발전을 위해서 함께 하겠다 이런 예정이었습니다. 마음도 차 한 따뜻하고 이거 뿐만 아니라 납작 복숭아 좀 먹었는데 이것도 쓱타콤해서 사전 이야기를 했는데 완판 500, 9000만 판됐다고 했는데. 좋은 일도 하고. 맞습니다. 그래서 제가 시뉘빙 선수와 직접 통화를 해보고 싶었어요. 어떻게 생각하는지. 그런데 지금 휴가 중이라고 합니다. 그래서 지금 매니저도 연락할 수가 없는 상황이었고 그래서 그냥 제가 문자로만 이야기를 받았는데 이렇게 얘기했습니다. 많은 사랑을 받아서 너무 감사하다. 광고 모델로 경험할 수 있는 기회를 그것때면 어딘 것 같고 다시 한번 응원해주신 분들에게 감사하고 앞으로 좋은 모습 보여드릴 수 있도록 노력하는 선수가 되겠다 이렇게 문자를 받았습니다. 시뉘빙 선수 외에도 올림픽 스타들이 광고의 모습을 드러내고 있잖아요. 맞습니다. 조금 전에 영상에도 나왔는데 맥주 회사에서는 펜싱사부로 국가 대표 오사흥우 선수. 훈남 너무 좋아하시는 것 같아요. 조정부터 좋아하신 것 같은데. 금메다 소식을 할리오 오사흥우 선수. 한국 선수로 최초로 개인전 커력 그리는 셀렴을 달성했죠. 그러다 보니까 여러 관심을 받았고 또 외모로도 가실을 받았습니다. 오빈 맥주가 인스타그램을 통해서 오사흥우 선수가 모델을 했으면 알렸고요. 이제 앞으로 이제 어떻게 활동하는지 천천히 밝힌다고 했습니다. 그런데 올림픽 스타들을 왜 원하는지 전문가 입장해서 좀 들어봤습니다. 그래요. 이번 올림픽에서 매달을 획득한 선수들의 경우에는 각종 예능에도 출연하고 있고 이미 대중적인 인지도와 관심을 받고 있기 때문에 각 기업들은 그런 부분들을 고려한 것이 아닌가 싶습니다. 그래서 올림픽 기간 동안 회득된 스포츠 스타일 어떤 인지도를 바탕으로 해서 당기적인 제품이나 서비스의 인지도를 높이기 위한 전략인 것으로 해석할 수 있을 것 같습니다. 한동안이 전략이 좀 계속될 것으로 보이죠. 신요비는 오상선수 외에도요. 사격의 김예지 선수. 김예지 선수는 어떤 브랜드 관골을 맡았나요. 명품이라고만 밝혔습니다. 명품 브랜드에서 화보 촬영을 하게 됐고요. 그리고 이제 소속사가 생겼어요. 소속사 측의 문의를 하고니까 앞으로 한 20개 정도 예정이 되어 있다 이렇게 지금 인터뷰를 한 것으로 나오고 있는데 자세한 건 나오진 않았습니다. 그리고 이제 일단은 예지 선수가 현재 건강을 완전히 회복한 상태고 현재는 대회에 집중만 하겠다 밝은 상황이에요. 그러니까 앞으로 저희 들이 관골을 통해서 어떻게 나온지 좀 보면 될 것 같고 이번에 저희가 예상 외로 참 좋은 성적을 거섰기 때문에 더 이미지가 좋은 부분이 있는 것 같아요. 그러다 보니까 기업식에서도 더 많은 선수들을 활용하지 않을까 이제 관고의 시간이다. 이거 좀 기다려 가지고 뽑아봤습니다. 잘 들었습니다. 반가운 소식이었고요. 또 관골도 찍고 좋은 일도 한다는 게 더 좋습니다. 잘 들었습니다. 오동원 기절 함께 했습니다. 고맙습니다. 고맙습니다.',
#  'segments': [{'id': 0,
#    'seek': 0,
#    'start': 0.0,
#    'end': 2.84,
#    'text': ' 다음 extension',
#    'tokens': [50414, 13526, 10320, 50506],
#    'temperature': 1.0,
#    'avg_logprob': -5.704884338378906,
#    'compression_ratio': 0.6666666666666666,
#    'no_speech_prob': 0.33596017956733704},
#   {'id': 1,
#    'seek': 3000,
#    'start': 30.0,
#    'end': 35.5,
#    'text': ' 이제는 광고의 시간 우리 오리픽 스타들 마케팅.',
#    'tokens': [50364,
#     8424,
#     1098,
#     26517,
#     1313,
#     2785,
#     16648,
#     8126,
#     10258,
#     2250,
#     8111,
#     121,
#     11196,
#     225,
#     2366,
#     2403,
#     6437,
#     36940,
#     27086,
#     13,
#     50639],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 2,
#    'seek': 3000,
#    'start': 35.5,
#    'end': 38.64,
#    'text': ' 광고 시작했더라고요.',
#    'tokens': [50639, 26517, 1313, 14525, 8697, 2196, 21261, 13, 50796],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 3,
#    'seek': 3000,
#    'start': 38.64,
#    'end': 39.6,
#    'text': ' 시럽에서 지도 했고.',
#    'tokens': [50796, 24452, 21498, 4885, 12205, 1838, 8154, 1313, 13, 50844],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 4,
#    'seek': 3000,
#    'start': 39.6,
#    'end': 42.4,
#    'text': ' 누구 제일 좀 관심 가지고 보셨습니까?',
#    'tokens': [50844,
#     36385,
#     23090,
#     6796,
#     47229,
#     21361,
#     7842,
#     227,
#     101,
#     32443,
#     30,
#     50984],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 5,
#    'seek': 3000,
#    'start': 42.4,
#    'end': 43.24,
#    'text': ' 시럽에서 지도.',
#    'tokens': [50984, 24452, 21498, 4885, 12205, 1838, 13, 51026],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 6,
#    'seek': 3000,
#    'start': 43.24,
#    'end': 44.24,
#    'text': ' 너무 귀엽잖아요.',
#    'tokens': [51026, 6924, 19112, 44944, 13928, 13, 51076],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 7,
#    'seek': 3000,
#    'start': 44.24,
#    'end': 44.84,
#    'text': ' 너무 귀엽고.',
#    'tokens': [51076, 6924, 19112, 44944, 1313, 13, 51106],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 8,
#    'seek': 3000,
#    'start': 44.84,
#    'end': 48.24,
#    'text': ' 특히 이제 먹방이 굉장히 좀 이슈가 됐을 거네요.',
#    'tokens': [51106,
#     37704,
#     8424,
#     6554,
#     27630,
#     1129,
#     15509,
#     6796,
#     4329,
#     232,
#     230,
#     1453,
#     16718,
#     1638,
#     15805,
#     12974,
#     13,
#     51276],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 9,
#    'seek': 3000,
#    'start': 48.24,
#    'end': 51.8,
#    'text': ' 저도 이렇게 일하다 보면 이렇게 안에 와서 바다 하나 계속 먹여서 그런',
#    'tokens': [51276,
#     27591,
#     5483,
#     7682,
#     25786,
#     19443,
#     5483,
#     4811,
#     1517,
#     45783,
#     12704,
#     1235,
#     12261,
#     17551,
#     6554,
#     10558,
#     2393,
#     9306,
#     51454],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 10,
#    'seek': 3000,
#    'start': 51.8,
#    'end': 52.84,
#    'text': ' 것도 있었습니다.',
#    'tokens': [51454, 25942, 15972, 3115, 13, 51506],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 11,
#    'seek': 3000,
#    'start': 52.84,
#    'end': 58.480000000000004,
#    'text': ' 자, 경기 중간중간 이렇게 뭐 바다나도 먹었고 주목받고 이게 또 다른',
#    'tokens': [51506,
#     5650,
#     11,
#     9537,
#     2401,
#     7596,
#     5989,
#     13907,
#     5989,
#     5483,
#     7034,
#     12704,
#     1235,
#     8580,
#     8226,
#     6554,
#     5642,
#     1313,
#     16410,
#     27523,
#     8672,
#     249,
#     1313,
#     10496,
#     7992,
#     16435,
#     51788],
#    'temperature': 0.0,
#    'avg_logprob': -0.5910542109241225,
#    'compression_ratio': 1.5731707317073171,
#    'no_speech_prob': 0.23723866045475006},
#   {'id': 12,
#    'seek': 5848,
#    'start': 58.48,
#    'end': 62.8,
#    'text': ' 재미이라고도 또 얘기했고 당시 누리꾼들이 광고조라 이런 댓글',
#    'tokens': [50364,
#     37723,
#     20438,
#     3744,
#     7992,
#     19641,
#     7077,
#     1313,
#     49559,
#     30225,
#     2250,
#     23536,
#     1870,
#     8109,
#     26517,
#     1313,
#     14327,
#     2004,
#     2742,
#     8381,
#     39765,
#     28311,
#     50580],
#    'temperature': 0.0,
#    'avg_logprob': -0.3767762617631392,
#    'compression_ratio': 1.5643044619422573,
#    'no_speech_prob': 0.2844794690608978},
#   {'id': 13,
#    'seek': 5848,
#    'start': 62.8,
#    'end': 65.52,
#    'text': ' 응원을 참 안 하는데 이게 현실로 일어졌습니다.',
#    'tokens': [50580,
#     21712,
#     7573,
#     1638,
#     18255,
#     4811,
#     29600,
#     10496,
#     17505,
#     1995,
#     38214,
#     7682,
#     2782,
#     5475,
#     3115,
#     13,
#     50716],
#    'temperature': 0.0,
#    'avg_logprob': -0.3767762617631392,
#    'compression_ratio': 1.5643044619422573,
#    'no_speech_prob': 0.2844794690608978},
#   {'id': 14,
#    'seek': 5848,
#    'start': 65.52,
#    'end': 70.52,
#    'text': ' GS 리테일이 운영하는 편의점 GS25 시뉘빙과 희벅판 주목받 또 소용량',
#    'tokens': [50716,
#     32047,
#     28227,
#     13433,
#     6403,
#     1129,
#     4709,
#     42978,
#     223,
#     7116,
#     16990,
#     2785,
#     15046,
#     32047,
#     6074,
#     24452,
#     231,
#     1894,
#     117,
#     247,
#     7097,
#     14473,
#     1698,
#     110,
#     227,
#     28306,
#     16410,
#     27523,
#     8672,
#     249,
#     7992,
#     10614,
#     8761,
#     167,
#     24502,
#     50966],
#    'temperature': 0.0,
#    'avg_logprob': -0.3767762617631392,
#    'compression_ratio': 1.5643044619422573,
#    'no_speech_prob': 0.2844794690608978},
#   {'id': 15,
#    'seek': 5848,
#    'start': 70.52,
#    'end': 72.67999999999999,
#    'text': ' 반찬 제품을 선거하고 했습니다.',
#    'tokens': [50966,
#     16396,
#     29434,
#     21496,
#     1638,
#     11835,
#     4285,
#     7040,
#     32314,
#     13,
#     51074],
#    'temperature': 0.0,
#    'avg_logprob': -0.3767762617631392,
#    'compression_ratio': 1.5643044619422573,
#    'no_speech_prob': 0.2844794690608978},
#   {'id': 16,
#    'seek': 5848,
#    'start': 72.67999999999999,
#    'end': 74.08,
#    'text': ' 또 빙그레는요.',
#    'tokens': [51074, 7992, 5005, 247, 10557, 10417, 1098, 1495, 13, 51144],
#    'temperature': 0.0,
#    'avg_logprob': -0.3767762617631392,
#    'compression_ratio': 1.5643044619422573,
#    'no_speech_prob': 0.2844794690608978},
#   {'id': 17,
#    'seek': 5848,
#    'start': 74.08,
#    'end': 78.88,
#    'text': ' 제날 16일에 이미 바다나마신한 우유의 모유의 모델로 시뉘빙 선수를',
#    'tokens': [51144,
#     23406,
#     24095,
#     3165,
#     6403,
#     1517,
#     30099,
#     12704,
#     1235,
#     48768,
#     8667,
#     7575,
#     3049,
#     14995,
#     19062,
#     2785,
#     11722,
#     19062,
#     2785,
#     8941,
#     235,
#     16270,
#     24452,
#     231,
#     1894,
#     117,
#     247,
#     11835,
#     45510,
#     51384],
#    'temperature': 0.0,
#    'avg_logprob': -0.3767762617631392,
#    'compression_ratio': 1.5643044619422573,
#    'no_speech_prob': 0.2844794690608978},
#   {'id': 18,
#    'seek': 5848,
#    'start': 78.88,
#    'end': 80.08,
#    'text': ' 발탑을 했습니다.',
#    'tokens': [51384, 13825, 6867, 239, 1638, 32314, 13, 51444],
#    'temperature': 0.0,
#    'avg_logprob': -0.3767762617631392,
#    'compression_ratio': 1.5643044619422573,
#    'no_speech_prob': 0.2844794690608978},
#   {'id': 19,
#    'seek': 5848,
#    'start': 80.08,
#    'end': 83.66,
#    'text': ' 빙그레는 오리픽 패막 직후에 시뉘빙 선수와 광고 모델 계약에',
#    'tokens': [51444,
#     5005,
#     247,
#     10557,
#     10417,
#     1098,
#     10258,
#     2250,
#     8111,
#     121,
#     6950,
#     3891,
#     47422,
#     19224,
#     26799,
#     1517,
#     24452,
#     231,
#     1894,
#     117,
#     247,
#     11835,
#     8449,
#     7590,
#     26517,
#     1313,
#     8941,
#     235,
#     116,
#     10603,
#     19970,
#     1517,
#     51623],
#    'temperature': 0.0,
#    'avg_logprob': -0.3767762617631392,
#    'compression_ratio': 1.5643044619422573,
#    'no_speech_prob': 0.2844794690608978},
#   {'id': 20,
#    'seek': 5848,
#    'start': 83.66,
#    'end': 84.66,
#    'text': ' 체결했고요.',
#    'tokens': [51623, 39667, 23466, 7077, 12364, 13, 51673],
#    'temperature': 0.0,
#    'avg_logprob': -0.3767762617631392,
#    'compression_ratio': 1.5643044619422573,
#    'no_speech_prob': 0.2844794690608978},
#   {'id': 21,
#    'seek': 5848,
#    'start': 84.66,
#    'end': 88.03999999999999,
#    'text': ' 이랬실에 영상광고 등을 촬영해서 공개할 예정입니다.',
#    'tokens': [51673,
#     2892,
#     252,
#     105,
#     8323,
#     1517,
#     15603,
#     36074,
#     1313,
#     15722,
#     1638,
#     27874,
#     8275,
#     9273,
#     11597,
#     7999,
#     10134,
#     6170,
#     7416,
#     13,
#     51842],
#    'temperature': 0.0,
#    'avg_logprob': -0.3767762617631392,
#    'compression_ratio': 1.5643044619422573,
#    'no_speech_prob': 0.2844794690608978},
#   {'id': 22,
#    'seek': 8804,
#    'start': 88.04,
#    'end': 92.60000000000001,
#    'text': ' 그런데 신선수 빙그레 광고 모델 이로건을 기부를 하기로 했습니다.',
#    'tokens': [50364,
#     16610,
#     13042,
#     12421,
#     8449,
#     5005,
#     247,
#     10557,
#     10417,
#     26517,
#     1313,
#     8941,
#     235,
#     116,
#     2892,
#     1955,
#     10619,
#     1638,
#     12503,
#     17981,
#     2429,
#     3369,
#     27860,
#     32314,
#     13,
#     50592],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 23,
#    'seek': 8804,
#    'start': 92.60000000000001,
#    'end': 93.80000000000001,
#    'text': ' 마음도 예뻐요.',
#    'tokens': [50592, 6437, 673, 33723, 45527, 1495, 13, 50652],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 24,
#    'seek': 8804,
#    'start': 93.80000000000001,
#    'end': 98.76,
#    'text': ' 한국 초등학교 타고 연낭에 기부를 해서 한국 타고 발전을 위해서',
#    'tokens': [50652,
#     21045,
#     34417,
#     22205,
#     48359,
#     19840,
#     1313,
#     34902,
#     224,
#     255,
#     1517,
#     12503,
#     17981,
#     2429,
#     17705,
#     21045,
#     19840,
#     1313,
#     13825,
#     8210,
#     1638,
#     30238,
#     50900],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 25,
#    'seek': 8804,
#    'start': 98.76,
#    'end': 101.04,
#    'text': ' 함께 하겠다 이런 예정이었습니다.',
#    'tokens': [50900,
#     21469,
#     3369,
#     19715,
#     8381,
#     10134,
#     6170,
#     25569,
#     3115,
#     13,
#     51014],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 26,
#    'seek': 8804,
#    'start': 101.04,
#    'end': 104.68,
#    'text': ' 마음도 차 한 따뜻하고 이거 뿐만 아니라 납작 복숭아 좀 먹었는데',
#    'tokens': [51014,
#     6437,
#     673,
#     33723,
#     15391,
#     4815,
#     15933,
#     250,
#     119,
#     7040,
#     7075,
#     25829,
#     25940,
#     22948,
#     2079,
#     102,
#     10492,
#     30696,
#     5500,
#     255,
#     2230,
#     6796,
#     6554,
#     27501,
#     51196],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 27,
#    'seek': 8804,
#    'start': 104.68,
#    'end': 108.46000000000001,
#    'text': ' 이것도 쓱타콤해서 사전 이야기를 했는데 완판 500, 9000만 판됐다고',
#    'tokens': [51196,
#     42118,
#     11647,
#     109,
#     25439,
#     15385,
#     97,
#     8275,
#     4744,
#     8210,
#     48974,
#     27418,
#     18112,
#     28306,
#     5923,
#     11,
#     1722,
#     1360,
#     5978,
#     6950,
#     2998,
#     35606,
#     7726,
#     51385],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 28,
#    'seek': 8804,
#    'start': 108.46000000000001,
#    'end': 109.46000000000001,
#    'text': ' 했는데.',
#    'tokens': [51385, 8154, 4189, 13, 51435],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 29,
#    'seek': 8804,
#    'start': 109.46000000000001,
#    'end': 110.46000000000001,
#    'text': ' 좋은 일도 하고.',
#    'tokens': [51435, 16460, 16623, 1838, 10301, 13, 51485],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 30,
#    'seek': 8804,
#    'start': 110.46000000000001,
#    'end': 111.46000000000001,
#    'text': ' 맞습니다.',
#    'tokens': [51485, 9172, 3115, 13, 51535],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 31,
#    'seek': 8804,
#    'start': 111.46000000000001,
#    'end': 114.36000000000001,
#    'text': ' 그래서 제가 시뉘빙 선수와 직접 통화를 해보고 싶었어요.',
#    'tokens': [51535,
#     8844,
#     7439,
#     24452,
#     231,
#     1894,
#     117,
#     247,
#     11835,
#     8449,
#     7590,
#     34196,
#     17006,
#     37859,
#     11134,
#     34400,
#     10785,
#     22415,
#     13,
#     51680],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 32,
#    'seek': 8804,
#    'start': 114.36000000000001,
#    'end': 115.36000000000001,
#    'text': ' 어떻게 생각하는지.',
#    'tokens': [51680, 12952, 8594, 7116, 1831, 13, 51730],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 33,
#    'seek': 8804,
#    'start': 115.36000000000001,
#    'end': 117.04,
#    'text': ' 그런데 지금 휴가 중이라고 합니다.',
#    'tokens': [51730,
#     16610,
#     7356,
#     30200,
#     112,
#     1453,
#     7596,
#     20438,
#     18802,
#     13,
#     51814],
#    'temperature': 0.0,
#    'avg_logprob': -0.5083348065957256,
#    'compression_ratio': 1.5918367346938775,
#    'no_speech_prob': 0.14337803423404694},
#   {'id': 34,
#    'seek': 11704,
#    'start': 117.04,
#    'end': 120.22000000000001,
#    'text': ' 그래서 지금 매니저도 연락할 수가 없는 상황이었고 그래서 그냥 제가',
#    'tokens': [50364,
#     8844,
#     7356,
#     17591,
#     1425,
#     2179,
#     33225,
#     34902,
#     20523,
#     7999,
#     27345,
#     20986,
#     24581,
#     25569,
#     1313,
#     8844,
#     11208,
#     7439,
#     50523],
#    'temperature': 0.0,
#    'avg_logprob': -0.27897410922580296,
#    'compression_ratio': 1.6131386861313868,
#    'no_speech_prob': 0.16804064810276031},
#   {'id': 35,
#    'seek': 11704,
#    'start': 120.22000000000001,
#    'end': 123.24000000000001,
#    'text': ' 문자로만 이야기를 받았는데 이렇게 얘기했습니다.',
#    'tokens': [50523,
#     13086,
#     11945,
#     1955,
#     5978,
#     48974,
#     12152,
#     48213,
#     5483,
#     19641,
#     14892,
#     13,
#     50674],
#    'temperature': 0.0,
#    'avg_logprob': -0.27897410922580296,
#    'compression_ratio': 1.6131386861313868,
#    'no_speech_prob': 0.16804064810276031},
#   {'id': 36,
#    'seek': 11704,
#    'start': 123.24000000000001,
#    'end': 125.68,
#    'text': ' 많은 사랑을 받아서 너무 감사하다.',
#    'tokens': [50674,
#     18494,
#     22581,
#     1638,
#     12152,
#     18461,
#     6924,
#     19538,
#     25786,
#     13,
#     50796],
#    'temperature': 0.0,
#    'avg_logprob': -0.27897410922580296,
#    'compression_ratio': 1.6131386861313868,
#    'no_speech_prob': 0.16804064810276031},
#   {'id': 37,
#    'seek': 11704,
#    'start': 125.68,
#    'end': 129.18,
#    'text': ' 광고 모델로 경험할 수 있는 기회를 그것때면 어딘 것 같고 다시 한번',
#    'tokens': [50796,
#     26517,
#     1313,
#     8941,
#     235,
#     16270,
#     9537,
#     24651,
#     7999,
#     4446,
#     7153,
#     7047,
#     11193,
#     29039,
#     32565,
#     167,
#     243,
#     2457,
#     2708,
#     41802,
#     246,
#     4431,
#     4385,
#     1313,
#     15463,
#     14463,
#     50971],
#    'temperature': 0.0,
#    'avg_logprob': -0.27897410922580296,
#    'compression_ratio': 1.6131386861313868,
#    'no_speech_prob': 0.16804064810276031},
#   {'id': 38,
#    'seek': 11704,
#    'start': 129.18,
#    'end': 132.8,
#    'text': ' 응원해주신 분들에게 감사하고 앞으로 좋은 모습 보여드릴 수 있도록',
#    'tokens': [50971,
#     21712,
#     7573,
#     25424,
#     7575,
#     20147,
#     15989,
#     19538,
#     7040,
#     30293,
#     16460,
#     27780,
#     33820,
#     29512,
#     4446,
#     23549,
#     19305,
#     51152],
#    'temperature': 0.0,
#    'avg_logprob': -0.27897410922580296,
#    'compression_ratio': 1.6131386861313868,
#    'no_speech_prob': 0.16804064810276031},
#   {'id': 39,
#    'seek': 11704,
#    'start': 132.8,
#    'end': 136.16,
#    'text': ' 노력하는 선수가 되겠다 이렇게 문자를 받았습니다.',
#    'tokens': [51152,
#     49388,
#     7116,
#     11835,
#     39621,
#     5514,
#     19715,
#     5483,
#     13086,
#     38134,
#     12152,
#     44353,
#     13,
#     51320],
#    'temperature': 0.0,
#    'avg_logprob': -0.27897410922580296,
#    'compression_ratio': 1.6131386861313868,
#    'no_speech_prob': 0.16804064810276031},
#   {'id': 40,
#    'seek': 11704,
#    'start': 136.16,
#    'end': 139.68,
#    'text': ' 시뉘빙 선수 외에도 올림픽 스타들이 광고의 모습을 드러내고 있잖아요.',
#    'tokens': [51320,
#     24452,
#     231,
#     1894,
#     117,
#     247,
#     11835,
#     8449,
#     27357,
#     21016,
#     12917,
#     15773,
#     8111,
#     121,
#     11196,
#     225,
#     2366,
#     8109,
#     26517,
#     1313,
#     2785,
#     27780,
#     1638,
#     13356,
#     7871,
#     22485,
#     1313,
#     38853,
#     13,
#     51496],
#    'temperature': 0.0,
#    'avg_logprob': -0.27897410922580296,
#    'compression_ratio': 1.6131386861313868,
#    'no_speech_prob': 0.16804064810276031},
#   {'id': 41,
#    'seek': 11704,
#    'start': 139.68,
#    'end': 140.68,
#    'text': ' 맞습니다.',
#    'tokens': [51496, 9172, 3115, 13, 51546],
#    'temperature': 0.0,
#    'avg_logprob': -0.27897410922580296,
#    'compression_ratio': 1.6131386861313868,
#    'no_speech_prob': 0.16804064810276031},
#   {'id': 42,
#    'seek': 11704,
#    'start': 140.68,
#    'end': 145.28,
#    'text': ' 조금 전에 영상에도 나왔는데 맥주 회사에서는 펜싱사부로 국가',
#    'tokens': [51546,
#     13091,
#     27117,
#     15603,
#     21016,
#     26374,
#     4189,
#     1747,
#     98,
#     5836,
#     22980,
#     5727,
#     23676,
#     10981,
#     250,
#     1995,
#     109,
#     14506,
#     17981,
#     1955,
#     13858,
#     1453,
#     51776],
#    'temperature': 0.0,
#    'avg_logprob': -0.27897410922580296,
#    'compression_ratio': 1.6131386861313868,
#    'no_speech_prob': 0.16804064810276031},
#   {'id': 43,
#    'seek': 14528,
#    'start': 145.28,
#    'end': 147.04,
#    'text': ' 대표 오사흥우 선수.',
#    'tokens': [50364,
#     37970,
#     5175,
#     5727,
#     9428,
#     98,
#     7812,
#     11835,
#     8449,
#     13,
#     50452],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 44,
#    'seek': 14528,
#    'start': 147.04,
#    'end': 148.6,
#    'text': ' 훈남 너무 좋아하시는 것 같아요.',
#    'tokens': [50452,
#     11091,
#     2196,
#     30856,
#     6924,
#     40344,
#     18147,
#     4431,
#     12196,
#     13,
#     50530],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 45,
#    'seek': 14528,
#    'start': 148.6,
#    'end': 150.4,
#    'text': ' 조정부터 좋아하신 것 같은데.',
#    'tokens': [50530, 7430, 6170, 39149, 40344, 7575, 4431, 21864, 13, 50620],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 46,
#    'seek': 14528,
#    'start': 150.4,
#    'end': 152.08,
#    'text': ' 금메다 소식을 할리오 오사흥우 선수.',
#    'tokens': [50620,
#     4291,
#     2196,
#     102,
#     242,
#     1235,
#     10614,
#     10436,
#     1638,
#     44148,
#     2250,
#     8920,
#     5175,
#     5727,
#     9428,
#     98,
#     7812,
#     11835,
#     8449,
#     13,
#     50704],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 47,
#    'seek': 14528,
#    'start': 152.08,
#    'end': 156.0,
#    'text': ' 한국 선수로 최초로 개인전 커력 그리는 셀렴을 달성했죠.',
#    'tokens': [50704,
#     21045,
#     11835,
#     25361,
#     1955,
#     14571,
#     15241,
#     2196,
#     1955,
#     36734,
#     8210,
#     39573,
#     11770,
#     2003,
#     20896,
#     23567,
#     2366,
#     254,
#     112,
#     1638,
#     21166,
#     8631,
#     7077,
#     5837,
#     13,
#     50900],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 48,
#    'seek': 14528,
#    'start': 156.0,
#    'end': 159.68,
#    'text': ' 그러다 보니까 여러 관심을 받았고 또 외모로도 가실을 받았습니다.',
#    'tokens': [50900,
#     14019,
#     1235,
#     25612,
#     31784,
#     47229,
#     1638,
#     12152,
#     9106,
#     1313,
#     7992,
#     4186,
#     1397,
#     40025,
#     1955,
#     3744,
#     4147,
#     8323,
#     1638,
#     12152,
#     44353,
#     13,
#     51084],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 49,
#    'seek': 14528,
#    'start': 159.68,
#    'end': 162.76,
#    'text': ' 오빈 맥주가 인스타그램을 통해서 오사흥우 선수가 모델을 했으면',
#    'tokens': [51084,
#     10258,
#     117,
#     230,
#     1747,
#     98,
#     5836,
#     1453,
#     9385,
#     44887,
#     50070,
#     1638,
#     17006,
#     8275,
#     5175,
#     5727,
#     9428,
#     98,
#     7812,
#     11835,
#     39621,
#     8941,
#     235,
#     116,
#     1638,
#     8154,
#     10819,
#     51238],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 50,
#    'seek': 14528,
#    'start': 162.76,
#    'end': 163.76,
#    'text': ' 알렸고요.',
#    'tokens': [51238, 21246, 14264, 12364, 13, 51288],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 51,
#    'seek': 14528,
#    'start': 163.76,
#    'end': 167.32,
#    'text': ' 이제 앞으로 이제 어떻게 활동하는지 천천히 밝힌다고 했습니다.',
#    'tokens': [51288,
#     8424,
#     30293,
#     8424,
#     12952,
#     45638,
#     7116,
#     1831,
#     31076,
#     18906,
#     5905,
#     26499,
#     169,
#     22855,
#     7726,
#     32314,
#     13,
#     51466],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 52,
#    'seek': 14528,
#    'start': 167.32,
#    'end': 171.76,
#    'text': ' 그런데 올림픽 스타들을 왜 원하는지 전문가 입장해서 좀 들어봤습니다.',
#    'tokens': [51466,
#     16610,
#     12917,
#     15773,
#     8111,
#     121,
#     11196,
#     225,
#     2366,
#     24968,
#     9883,
#     13499,
#     7116,
#     1831,
#     19617,
#     8357,
#     1453,
#     10051,
#     4573,
#     8275,
#     6796,
#     46088,
#     23560,
#     3115,
#     13,
#     51688],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 53,
#    'seek': 14528,
#    'start': 171.76,
#    'end': 172.76,
#    'text': ' 그래요.',
#    'tokens': [51688, 47453, 13, 51738],
#    'temperature': 0.0,
#    'avg_logprob': -0.4436632792154948,
#    'compression_ratio': 1.6649076517150396,
#    'no_speech_prob': 0.5447425842285156},
#   {'id': 54,
#    'seek': 17276,
#    'start': 172.76,
#    'end': 180.6,
#    'text': ' 이번 올림픽에서 매달을 획득한 선수들의 경우에는 각종 예능에도',
#    'tokens': [50364,
#     16299,
#     12917,
#     15773,
#     8111,
#     121,
#     4885,
#     17591,
#     24673,
#     1638,
#     14794,
#     235,
#     167,
#     26152,
#     3049,
#     11835,
#     25361,
#     29990,
#     45745,
#     28378,
#     17273,
#     10134,
#     16102,
#     21016,
#     50756],
#    'temperature': 0.0,
#    'avg_logprob': -0.2278236709274612,
#    'compression_ratio': 1.5923753665689149,
#    'no_speech_prob': 0.20988979935646057},
#   {'id': 55,
#    'seek': 17276,
#    'start': 180.6,
#    'end': 185.2,
#    'text': ' 출연하고 있고 이미 대중적인 인지도와 관심을 받고 있기 때문에 각',
#    'tokens': [50756,
#     25420,
#     11557,
#     7040,
#     18683,
#     30099,
#     5971,
#     13907,
#     17495,
#     9385,
#     39871,
#     7590,
#     47229,
#     1638,
#     48130,
#     48371,
#     12365,
#     28378,
#     50986],
#    'temperature': 0.0,
#    'avg_logprob': -0.2278236709274612,
#    'compression_ratio': 1.5923753665689149,
#    'no_speech_prob': 0.20988979935646057},
#   {'id': 56,
#    'seek': 17276,
#    'start': 185.2,
#    'end': 188.79999999999998,
#    'text': ' 기업들은 그런 부분들을 고려한 것이 아닌가 싶습니다.',
#    'tokens': [50986,
#     7047,
#     11534,
#     14271,
#     2124,
#     9306,
#     10201,
#     18912,
#     1638,
#     18556,
#     5743,
#     3049,
#     29665,
#     28069,
#     1453,
#     10785,
#     3115,
#     13,
#     51166],
#    'temperature': 0.0,
#    'avg_logprob': -0.2278236709274612,
#    'compression_ratio': 1.5923753665689149,
#    'no_speech_prob': 0.20988979935646057},
#   {'id': 57,
#    'seek': 17276,
#    'start': 188.79999999999998,
#    'end': 192.57999999999998,
#    'text': ' 그래서 올림픽 기간 동안 회득된 스포츠 스타일 어떤 인지도를 바탕으로',
#    'tokens': [51166,
#     8844,
#     12917,
#     15773,
#     8111,
#     121,
#     7047,
#     5989,
#     32589,
#     14794,
#     2457,
#     26152,
#     27930,
#     11196,
#     237,
#     105,
#     34130,
#     45881,
#     15620,
#     9385,
#     39871,
#     11297,
#     12704,
#     47780,
#     4130,
#     51355],
#    'temperature': 0.0,
#    'avg_logprob': -0.2278236709274612,
#    'compression_ratio': 1.5923753665689149,
#    'no_speech_prob': 0.20988979935646057},
#   {'id': 58,
#    'seek': 17276,
#    'start': 192.57999999999998,
#    'end': 197.48,
#    'text': ' 해서 당기적인 제품이나 서비스의 인지도를 높이기 위한 전략인 것으로',
#    'tokens': [51355,
#     17705,
#     12047,
#     2401,
#     17495,
#     21496,
#     21672,
#     32558,
#     9790,
#     7785,
#     2785,
#     9385,
#     39871,
#     11297,
#     25015,
#     1129,
#     2401,
#     41475,
#     19617,
#     252,
#     113,
#     4215,
#     34071,
#     51600],
#    'temperature': 0.0,
#    'avg_logprob': -0.2278236709274612,
#    'compression_ratio': 1.5923753665689149,
#    'no_speech_prob': 0.20988979935646057},
#   {'id': 59,
#    'seek': 17276,
#    'start': 197.48,
#    'end': 199.39999999999998,
#    'text': ' 해석할 수 있을 것 같습니다.',
#    'tokens': [51600,
#     7960,
#     226,
#     251,
#     7999,
#     4446,
#     18082,
#     4431,
#     31297,
#     13,
#     51696],
#    'temperature': 0.0,
#    'avg_logprob': -0.2278236709274612,
#    'compression_ratio': 1.5923753665689149,
#    'no_speech_prob': 0.20988979935646057},
#   {'id': 60,
#    'seek': 17276,
#    'start': 199.39999999999998,
#    'end': 201.32,
#    'text': ' 한동안이 전략이 좀 계속될 것으로 보이죠.',
#    'tokens': [51696,
#     10737,
#     48608,
#     1129,
#     19617,
#     252,
#     113,
#     1129,
#     6796,
#     17551,
#     25041,
#     254,
#     34071,
#     6330,
#     27036,
#     13,
#     51792],
#    'temperature': 0.0,
#    'avg_logprob': -0.2278236709274612,
#    'compression_ratio': 1.5923753665689149,
#    'no_speech_prob': 0.20988979935646057},
#   {'id': 61,
#    'seek': 20132,
#    'start': 201.32,
#    'end': 202.78,
#    'text': ' 신요비는 오상선수 외에도요.',
#    'tokens': [50364,
#     13042,
#     1495,
#     39066,
#     1098,
#     5175,
#     5979,
#     12421,
#     8449,
#     27357,
#     21016,
#     1495,
#     13,
#     50437],
#    'temperature': 0.0,
#    'avg_logprob': -0.3384271867436134,
#    'compression_ratio': 1.636604774535809,
#    'no_speech_prob': 0.25751417875289917},
#   {'id': 62,
#    'seek': 20132,
#    'start': 202.78,
#    'end': 204.5,
#    'text': ' 사격의 김예지 선수.',
#    'tokens': [50437,
#     4744,
#     15231,
#     2785,
#     17376,
#     9170,
#     1831,
#     11835,
#     8449,
#     13,
#     50523],
#    'temperature': 0.0,
#    'avg_logprob': -0.3384271867436134,
#    'compression_ratio': 1.636604774535809,
#    'no_speech_prob': 0.25751417875289917},
#   {'id': 63,
#    'seek': 20132,
#    'start': 204.5,
#    'end': 207.29999999999998,
#    'text': ' 김예지 선수는 어떤 브랜드 관골을 맡았나요.',
#    'tokens': [50523,
#     17376,
#     9170,
#     1831,
#     11835,
#     8449,
#     1098,
#     15620,
#     21886,
#     27273,
#     7087,
#     21061,
#     1155,
#     101,
#     1638,
#     49132,
#     36501,
#     26057,
#     13,
#     50663],
#    'temperature': 0.0,
#    'avg_logprob': -0.3384271867436134,
#    'compression_ratio': 1.636604774535809,
#    'no_speech_prob': 0.25751417875289917},
#   {'id': 64,
#    'seek': 20132,
#    'start': 207.29999999999998,
#    'end': 209.18,
#    'text': ' 명품이라고만 밝혔습니다.',
#    'tokens': [50663, 18284, 13936, 20438, 5978, 48437, 3115, 13, 50757],
#    'temperature': 0.0,
#    'avg_logprob': -0.3384271867436134,
#    'compression_ratio': 1.636604774535809,
#    'no_speech_prob': 0.25751417875289917},
#   {'id': 65,
#    'seek': 20132,
#    'start': 209.18,
#    'end': 212.51999999999998,
#    'text': ' 명품 브랜드에서 화보 촬영을 하게 됐고요.',
#    'tokens': [50757,
#     18284,
#     13936,
#     21886,
#     27273,
#     7087,
#     4885,
#     26700,
#     7062,
#     27874,
#     1638,
#     44605,
#     16718,
#     12364,
#     13,
#     50924],
#    'temperature': 0.0,
#    'avg_logprob': -0.3384271867436134,
#    'compression_ratio': 1.636604774535809,
#    'no_speech_prob': 0.25751417875289917},
#   {'id': 66,
#    'seek': 20132,
#    'start': 212.51999999999998,
#    'end': 214.22,
#    'text': ' 그리고 이제 소속사가 생겼어요.',
#    'tokens': [50924, 8785, 8424, 10614, 11194, 34435, 49810, 4213, 13, 51009],
#    'temperature': 0.0,
#    'avg_logprob': -0.3384271867436134,
#    'compression_ratio': 1.636604774535809,
#    'no_speech_prob': 0.25751417875289917},
#   {'id': 67,
#    'seek': 20132,
#    'start': 214.22,
#    'end': 220.04,
#    'text': ' 소속사 측의 문의를 하고니까 앞으로 한 20개 정도 예정이 되어 있다',
#    'tokens': [51009,
#     10614,
#     11194,
#     5727,
#     41696,
#     2785,
#     13086,
#     673,
#     18855,
#     10301,
#     5690,
#     30293,
#     4815,
#     945,
#     11597,
#     13636,
#     10134,
#     38676,
#     41210,
#     27468,
#     51300],
#    'temperature': 0.0,
#    'avg_logprob': -0.3384271867436134,
#    'compression_ratio': 1.636604774535809,
#    'no_speech_prob': 0.25751417875289917},
#   {'id': 68,
#    'seek': 20132,
#    'start': 220.04,
#    'end': 224.04,
#    'text': ' 이렇게 지금 인터뷰를 한 것으로 나오고 있는데 자세한 건 나오진 않았습니다.',
#    'tokens': [51300,
#     5483,
#     7356,
#     47491,
#     115,
#     38220,
#     4815,
#     34071,
#     19857,
#     1313,
#     19197,
#     5650,
#     5762,
#     3049,
#     13507,
#     19857,
#     8097,
#     29558,
#     3115,
#     13,
#     51500],
#    'temperature': 0.0,
#    'avg_logprob': -0.3384271867436134,
#    'compression_ratio': 1.636604774535809,
#    'no_speech_prob': 0.25751417875289917},
#   {'id': 69,
#    'seek': 20132,
#    'start': 224.04,
#    'end': 228.64,
#    'text': ' 그리고 이제 일단은 예지 선수가 현재 건강을 완전히 회복한 상태고 현재',
#    'tokens': [51500,
#     8785,
#     8424,
#     17304,
#     2124,
#     10134,
#     1831,
#     11835,
#     39621,
#     39870,
#     13507,
#     24888,
#     1638,
#     25587,
#     5905,
#     14794,
#     2457,
#     32635,
#     3049,
#     34210,
#     1313,
#     39870,
#     51730],
#    'temperature': 0.0,
#    'avg_logprob': -0.3384271867436134,
#    'compression_ratio': 1.636604774535809,
#    'no_speech_prob': 0.25751417875289917},
#   {'id': 70,
#    'seek': 20132,
#    'start': 228.64,
#    'end': 231.2,
#    'text': '는 대회에 집중만 하겠다 밝은 상황이에요.',
#    'tokens': [51730,
#     1098,
#     5971,
#     15048,
#     1517,
#     12111,
#     13907,
#     5978,
#     3369,
#     19715,
#     26499,
#     2124,
#     24581,
#     15099,
#     13,
#     51858],
#    'temperature': 0.0,
#    'avg_logprob': -0.3384271867436134,
#    'compression_ratio': 1.636604774535809,
#    'no_speech_prob': 0.25751417875289917},
#   {'id': 71,
#    'seek': 23120,
#    'start': 231.2,
#    'end': 235.72,
#    'text': ' 그러니까 앞으로 저희 들이 관골을 통해서 어떻게 나온지 좀 보면 될 것 같고',
#    'tokens': [50364,
#     20855,
#     30293,
#     14594,
#     6275,
#     1129,
#     21061,
#     1155,
#     101,
#     1638,
#     17006,
#     8275,
#     12952,
#     34396,
#     1831,
#     6796,
#     19443,
#     16625,
#     4431,
#     4385,
#     1313,
#     50590],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 72,
#    'seek': 23120,
#    'start': 235.72,
#    'end': 239.76,
#    'text': ' 이번에 저희가 예상 외로 참 좋은 성적을 거섰기 때문에 더 이미지가',
#    'tokens': [50590,
#     40692,
#     27463,
#     10134,
#     5979,
#     4186,
#     16270,
#     18255,
#     16460,
#     14409,
#     7554,
#     1638,
#     3675,
#     1645,
#     108,
#     2401,
#     12365,
#     6990,
#     30099,
#     30232,
#     50792],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 73,
#    'seek': 23120,
#    'start': 239.76,
#    'end': 240.79999999999998,
#    'text': ' 좋은 부분이 있는 것 같아요.',
#    'tokens': [50792, 16460, 47820, 7153, 4431, 12196, 13, 50844],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 74,
#    'seek': 23120,
#    'start': 240.79999999999998,
#    'end': 245.23999999999998,
#    'text': ' 그러다 보니까 기업식에서도 더 많은 선수들을 활용하지 않을까 이제',
#    'tokens': [50844,
#     14019,
#     1235,
#     25612,
#     7047,
#     11534,
#     10436,
#     40963,
#     6990,
#     18494,
#     11835,
#     25361,
#     24968,
#     42194,
#     8761,
#     16175,
#     32112,
#     3294,
#     8424,
#     51066],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 75,
#    'seek': 23120,
#    'start': 245.23999999999998,
#    'end': 246.76,
#    'text': ' 관고의 시간이다.',
#    'tokens': [51066, 21061, 1313, 2785, 16648, 22158, 13, 51142],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 76,
#    'seek': 23120,
#    'start': 246.76,
#    'end': 248.64,
#    'text': ' 이거 좀 기다려 가지고 뽑아봤습니다.',
#    'tokens': [51142,
#     7075,
#     6796,
#     31431,
#     5743,
#     21361,
#     38473,
#     23733,
#     23560,
#     3115,
#     13,
#     51236],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 77,
#    'seek': 23120,
#    'start': 248.64,
#    'end': 249.64,
#    'text': ' 잘 들었습니다.',
#    'tokens': [51236, 6644, 6275, 24148, 13, 51286],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 78,
#    'seek': 23120,
#    'start': 249.64,
#    'end': 250.64,
#    'text': ' 반가운 소식이었고요.',
#    'tokens': [51286, 16396, 1453, 9996, 10614, 10436, 25569, 12364, 13, 51336],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 79,
#    'seek': 23120,
#    'start': 250.64,
#    'end': 253.48,
#    'text': ' 또 관골도 찍고 좋은 일도 한다는 게 더 좋습니다.',
#    'tokens': [51336,
#     7992,
#     21061,
#     1155,
#     101,
#     3744,
#     17285,
#     1313,
#     16460,
#     16623,
#     1838,
#     4815,
#     10520,
#     7845,
#     6990,
#     5008,
#     3115,
#     13,
#     51478],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 80,
#    'seek': 23120,
#    'start': 253.48,
#    'end': 254.48,
#    'text': ' 잘 들었습니다.',
#    'tokens': [51478, 6644, 6275, 24148, 13, 51528],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 81,
#    'seek': 23120,
#    'start': 254.48,
#    'end': 255.6,
#    'text': ' 오동원 기절 함께 했습니다.',
#    'tokens': [51528, 10258, 8309, 7573, 7047, 23583, 21469, 32314, 13, 51584],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 82,
#    'seek': 23120,
#    'start': 255.6,
#    'end': 256.59999999999997,
#    'text': ' 고맙습니다.',
#    'tokens': [51584, 9161, 3468, 247, 3115, 13, 51634],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258},
#   {'id': 83,
#    'seek': 23120,
#    'start': 256.59999999999997,
#    'end': 257.59999999999997,
#    'text': ' 고맙습니다.',
#    'tokens': [51634, 9161, 3468, 247, 3115, 13, 51684],
#    'temperature': 0.0,
#    'avg_logprob': -0.3905229021789162,
#    'compression_ratio': 1.7386363636363635,
#    'no_speech_prob': 0.3361462652683258}],
#  'language': 'ko'}

# %%
import whisper

wav_file = 'sol7.wav'

model = whisper.load_model("base")
result = model.transcribe(wav_file)
print(result["text"])

# %%
# 번역
# !whisper "librodepoemas_04_garcialorca.mp3" --task translate
