# %% [markdown]
# # RAG - 2. Loaders
#
# > 1) 문서 읽어들이는 작업
# > 2) 목적 : 다양한 종류의 문서를 읽어들이기
# > 3) 확장해보기 : url, pdf, 폴더, text, office, youttube등으로 확장
# > 4) 선행작업 :
#
# > 아래의 샘플 문서를 직접 자신의 PC에 업로드해서, 변경해서 사용한다.

# %%
#1) text 읽기

from langchain_community.document_loaders import TextLoader

loader = TextLoader("./news_data.txt")
loader.load()
# Out:
# [Document(metadata={'source': './news_data.txt'}, page_content='[속보] 비트코인, 사상 첫 7만4000달러 돌파…이더리움·도지코인도 상승\n추천 기사\n이상현 기자 lee.sanghyun@mkinternet.com\n입력 :  2024-11-06 12:14:18 수정 :  2024-11-06 12:39:50\n가상화폐 대장주 비트코인이 미국 대통령 선거 당일 처음으로 7만4000달러선을 돌파하며 사상 최고가를 경신했다.\n6일(현지시간) 미 가상화폐 거래소 코인베이스에 따르면 미 동부 시간 이날 오후 10시 10분(서부 시간 오후 8시 10분) 비트코인 1개당 가격은 24시간 전보다 8.97% 급등한 7만4033달러를 나타냈다.\n비트코인은 지난 3월 13일 기록했던 7만3800달러대를 뛰어넘으며 이날 사상 처음 7만4000달러대를 돌파했다.\n이날 한때는 7만4900달러대까지 치솟으며 7만5000달러선 돌파도 목전에 뒀다.\n비트코인 가격 급등은 미 대선 개표가 시작된 가운데 장 초반 친(親)가상화폐 행보를 보여온 도널드 트럼프 전 대통령의 당선 가능성에 대한 기대감이 반영된 것으로 보인다.\n같은 시간 시가총액 2위 이더리움은 8.34% 뛰었고, 일론 머스크 테슬라 최고경영자가 띄우는 도지코인은 28% 폭등했다.\n\nAP통신에 따르면 한국시간으로 6일 오후 12시 30분 현재 트럼프 전 대통령은 7개 경합주를 제외한 나머지 선거구에서 198명의 선거인단을 확보해 112명을 기록 중인 해리스 부통령에 앞서 있다.')]

# %%
#2) pdf 읽기


from langchain_community.document_loaders import PyPDFLoader

loader = PyPDFLoader("Prompt_Engineering_For_ChatGPT_A_Quick_Guide_To_Te.pdf")
pages = loader.load_and_split()

# %%
pages[0]
# Out:
# Document(metadata={'source': 'Prompt_Engineering_For_ChatGPT_A_Quick_Guide_To_Te.pdf', 'page': 0}, page_content='PROMPT ENGINEERING FOR CHATGPT\nA Q UICK GUIDE TO TECHNIQUES , TIPS,AND BESTPRACTICES\nLearn from the Best: Let Genie (ChatGPT) teach you how to make wise Wishes (Prompts)\nChatGPT 4 (author)\nOpenAI\nOpenAI.comSabit Ekin (prompt engineer)\nTexas A&M University\nsabitekin@tamu.edu\nABSTRACT\nIn the rapidly evolving landscape of natural language processing (NLP), ChatGPT has emerged as\na powerful tool for various industries and applications. To fully harness the potential of ChatGPT,\nit is crucial to understand and master the art of prompt engineering—the process of designing and\nrefining input prompts to elicit desired responses from an AI NLP model. This article provides\na comprehensive guide to mastering prompt engineering techniques, tips, and best practices to\nachieve optimal outcomes with ChatGPT. The discussion begins with an introduction to ChatGPT\nand the fundamentals of prompt engineering, followed by an exploration of techniques for effective\nprompt crafting, such as clarity, explicit constraints, experimentation, and leveraging different\ntypes of questions. The article also covers best practices, including iterative refinement, balancing\nuser intent, harnessing external resources, and ensuring ethical usage. Advanced strategies, such\nas temperature and token control, prompt chaining, domain-specific adaptations, and handling\nambiguous inputs, are also addressed. Real-world case studies demonstrate the practical applications\nof prompt engineering in customer support, content generation, domain-specific knowledge retrieval,\nand interactive storytelling. The article concludes by highlighting the impact of effective prompt\nengineering on ChatGPT performance, future research directions, and the importance of fostering\ncreativity and collaboration within the ChatGPT community.\nThis article was generated using OpenAI’s ChatGPT [ 1] with prompts provided by Sabit Ekin, who also reviewed and edited the\ncontent.\nKeywords ChatGPT ·Prompt Engineering ·Prompt Engineer ·Generative Pre-trained Transformer (GPT) ·Natural Language\nProcessing (NLP) ·Large Language Models (LLM)\nImage: Created with DALL-E 2 by OpenAI')

# %%
#3) url 읽기


#!pip install bs4

from langchain_community.document_loaders import UnstructuredURLLoader

urls = [
    "https://www.etnews.com/20241105000218?mc=ns_004_00001",
    "https://www.understandingwar.org/backgrounder/russian-offensive-campaign-assessment-february-9-2023",
]

loader = UnstructuredURLLoader(urls=urls)
data = loader.load()
data
# Out:
# [Document(metadata={'source': 'https://www.etnews.com/20241105000218?mc=ns_004_00001'}, page_content="IT\n\n통신\n\n中 폴더블폰의 역습…폼팩터·자체 OS로 위협\n\n2024-11-06 4면\n\n페이스북\n\nX(트위터)\n\n메일\n\nURL 복사\n\n가\n                    작게\n\n가\n\t\t\t\t    보통\n\n가\n                    크게\n\n중국 휴대폰 제조사들의 폴더블 스마트폰 공세가 거세다. 조악했던 단말 완성도를 몇 년 만에 수준급으로 끌어올리고 있다. 폴더블 스마트폰의 상품성을 가르는 핵심 요소인 '얇기'와 '무게'는 세계 최고 수준으로 올랐다.\n\n중국 제조사들은 기존 하드웨어(HW)를 강화하는 전략을 넘어 소프트웨어(SW) 확장도 추진하고 있다. 독립적인 운용체계(OS)를 구축해 자신들의 서비스를 강화하고 SW 독자노선을 걷고 있다.\n\n◇중국 현지 폴더블폰...“얇고 가볍다”\n\n최근 방문한 중국 광둥성 선전시에서는 중국의 폴더블 스마트폰 기술력을 체감할 수 있었다. 제품은 일반 바(Bar)형 스마트폰과 견줄 정도로 가볍고, 두께는 얇았다. 하드웨어 측면 뿐 아니라 소프트웨어에서의 비약적 발전을 이룬 모습이었다.\n\n샤오미 4세대 폴드형 스마트폰 '믹스 폴드4(MIX Fold 4)'가 대표적이다. 이 제품은 펼쳤을 때 두께 4.59mm, 접었을 때 두께 9.47mm이다. 작년에 출시한 믹스 폴드3 두께(5.4mm·10.86mm)보다 얇다. 2021년 첫선을 보인 1세대 제품 두께가 각각 7.6mm, 17.2mm인 점을 고려했을 때 상당한 얇기 변화를 이뤄냈다. 제품 무게(226g) 또한 3세대 255g에서 29g 덜어냈다. 1세대 무게 317g과 비교해선 91g가량을 줄였다.\n\n선전시내 한 샤오미 매장 관계자는 “믹스폴드 시리즈는 많은 문의가 있는 제품”이라며 “얇기도 얇지만, 카메라 성능이 뛰어나다”고 믹스폴드4를 소개했다.\n\n실제 카메라 성능은 수준급이었다. 독일 명품 카메라 업체 라이카와 협업해 만든 쿼드 카메라 시스템은 다양한 촬영 환경에 맞는 결과물을 보여줬다. 카메라 줌을 최대치인 50배까지 끌어올려도 흔들림이 적었다. 일각에선 “카메라만 켜면 발열이 심해진다”는 지적이 나오긴 했으나, 실제 체험 시간에는 발열을 느끼지 못했다.\n\n중국 제조사 중 가장 얇은 폴더블폰을 보유한 곳은 화웨이에서 분사한 아너다. 이들은 2022년 1월 매직V를 출시한 이래 줄곧 얇기와 무게를 중점으로 기술력을 발전시켰다. 첫 제품인 매직V는 접었을 때 14.3mm, 펼쳤을 때 6.7mm로 두꺼운 수준이었다. 최신작인 3세대 매직V3의 경우 접었을 때 9.2mm, 펼쳤을 때 4.35mm로 줄여냈다. 무게 또한 1세대 288g에서 226g으로 가벼워졌다. 세계 폴더블 스마트폰 제품 중 가장 얇은 제품이자 가벼운 제품군이다.\n\n아너는 자사 제품이 얇고 가볍다는 점을 강조하는 마케팅을 구사한다. 제품 공개 행사장에서 삼성전자 폴더블폰 두께를 저격하는 마케팅이 대표적이다. 조지 자오 아너 최고경영자(CEO)는 올해 9월 독일 베를린에서 열린 유럽 최대 가전 전시회 IFA 행사장에서 매직V3와 삼성 갤럭시Z폴드6 두께를 직접 비교했다. 그는 매직V3에 대해 “세상에서 가장 얇은 폴더블폰”이라며 삼성 제품보다 얇고 애플 아이폰보다 가볍다고 말했다.\n\n실제 매직V3를 손에 쥐자 가볍고 얇다는 느낌이 강했다. 디스플레이를 접은 채 손에 쥐니 일반 바형 스마트폰보다 가볍다는 느낌이 들 정도였다. 아너의 '슈퍼 스틸'이 적용된 힌지(경첩)부분은 과거보다 견고해졌다. 아너 관계자에 따르면 매직V3 힌지 강도는 약 2100 메가파스칼(MPa)이다. 이는 일반적 티타늄 합금의 강도보다 강한 정도다.\n\n◇자체 OS개발 기업 증가…화웨이는 사업 확장도\n\n중국 스마트폰 제조사들은 하드웨어뿐 아니라 자체 OS를 구축하고 있다. 제품 간 OS 생태계를 보다 강하게 연결하기 위해서다. 앞으로 발생할 수 있는 미국 제재에 대한 대비책이기도 하다.\n\n자체 OS를 개발한 중국 제조사는 화웨이(훙멍 OS), 샤오미(하이퍼OS), 오포(칼라OS), 비보(오리진OS) 등 점차 늘어나고 있다. 구글 안드로이드를 기반으로 UI·UX를 만들고 중국 개발자 애플리케이션(앱)을 최적화해 현지 사용자들 편의성을 높인 게 특징이다.\n\n이들의 OS 독자 개발은 자사 기기 간 연결성을 높여 소비자들을 자사 제품 생태계에 묶어두는 '락인 효과(Lock-in effect)'를 거두기 위한 전략이다. 독자 OS를 갖고 있는 애플은 이같은 전략을 활용해 스마트폰뿐 아니라 모든 제품군의 일류 기업으로 성장했다.\n\n화웨이는 자체 OS '훙멍(鴻蒙·하모니)' 대중화에 성공한 중국 기업이다. 현지 외신 등에 따르면 훙멍 OS가 설치된 모바일 기기는 10억대가 넘는다. 안드로이드 OS에 이어 2위 점유율이다. 최근에는 홍멍 NEXT라는 신규 OS도 선보였다. 해당 OS에는 1만5000여개의 기본 앱과 서비스들이 들어갔다.\n\n훙멍 OS는 화웨이 스마트폰, 집안의 가전·가구 등 모든 화웨이 제품에 탑재된다. TV와 노트북, 집안의 가전, 전기차 등을 모바일로 제어하고 활용할 수 있어 사용 편의성이 높다.\n\n훙멍 OS는 사업 확장 측면에서도 도움을 받고 있다. 화웨이는 전기차를 직접 생산하지 않지만, 전기차 사업을 전개하고 있다. 자동차 제조사들과 협업해 이들의 전기차에 훙멍 OS를 입히는 방식이다. 현재 중국 자동차 기업 베이징자동차그룹, 비야디(BYD), 체리차 등과 협업 중이다.\n\n선전(중국)=\n\n남궁경 기자 nkk@etnews.com\n\n남궁경 기자기사 더보기\n\t\t\tSKT, 3분기 영업익 5333억…AI수익화 속도\n\n\n\n\n\nIT 많이 본 기사\n\n1쿠팡, '블랙 프라이데이' 앞두고 가전·디지털 할인전…최대 75% 세일\n                  2서초 서리풀 그린벨트 푼다…고양·의왕·의정부 신규택지 5만호 공급\n                  3삼성전자·LG전자, 내년 TV OS 확대 …보급형 라인업도 늘릴 듯\n                  4쿠팡, 3분기 매출 10조6900억 '역대 최대'...고객도 11% 증가\n                  5엔비디아, 애플 꺾고 전세계 시총 1위 등극\n\n6태국 왕, 26세 연하 네 번째 왕비와 초호화 생일잔치\n                  7[2024 美 대선] 트럼프, 美대선 승리선언…“47대 대통령 당선 영광”\n                  8KT, '온디바이스 AI'에 '8K 화질' 더한 셋톱박스 공개…“IPTV를 AI 허브로”\n                  9LG엔솔, 배터리SW 사업화…현대차와 사용료 협상\n                  10외산 장비 설 곳 잃어가는 中 반도체 시장\n\n주요 행사 ❯\n\n엔터프라이즈 하이퍼오토메이션 코리아 그랜드 서밋 2024-Fall\n\n코딩 없이 회사에 필요한 GPTs 앱 개발 워크숍:GPT-4o로 누구나 AI챗봇에서부터 업무자동화 GPTs 앱까\n\n생성형 AI와 데이터 분석의 혁신적 접근\n\nG-star 가기 전 꼭 확인해 볼 Gaming Solution 및 트렌드 체크\n\n제19회 스마트금융 콘퍼런스 & 제4회 대한민국 스마트금융 대상\n\nGPT-4o 활용 전략적 의사결정 위한 데이터 분석 & 업무 자동화 GPTs 앱 개발 1-day 워크숍\n\n2025년도 성공적인 글로벌 확장을 위한 AX무역·투자·ESG 전략 공유 세미나\n\n2024 글로벌 소재부품장비 테크페어\n\nBIZPLUS\n\n[올쇼TV] 생성형 AI와 데이터 분석의 혁신적 접근 11월 12일 생방송\n\n[올쇼TV] 의료 상호운영성과 헬스케어의 미래 11월 7일 생방송\n\n현장에서 듣는 의료기기 소프트웨어 테스트와 보안의 궁금증, 여기서 답하다! 11월 7일 생방송\n\n[올쇼TV] 제품디자인 개발 효율성 증진을 위한 오토데스크 퓨전 활용 11월 7일 생방송\n\nHOT 영상 ❯\ ...
#  Document(metadata={'source': 'https://www.understandingwar.org/backgrounder/russian-offensive-campaign-assessment-february-9-2023'}, page_content='Skip to main content\n\nSearch form\n\nHome\n\nWho We Are\n\nResearch\n\nPublications\n\nGet Involved\n\nPlanned Giving\n\nDonate\n\nRussian Offensive Campaign Assessment, February 9, 2023\n\nFeb 9, 2023 - ISW Press\n\nDownload the PDF\n\nKarolina Hird, Riley Bailey, George Barros, Nicole Wolkov, and Frederick W. Kagan\n\nFebruary 9, 7:30 pm ET\n\nClick here to see ISW’s interactive map of the Russian invasion of Ukraine. This map is updated daily alongside the static maps present in this report.\n\nWagner Group financier Yevgeny Prigozhin announced on February 9 that the Wagner Group has entirely stopped recruiting prisoners.\xa0In a response to a press comment, Prigozhin claimed that Wagner’s recruitment of prisoners has "completely stopped" and that "all obligations are being fulfilled" for those currently under Wagner’s employ.[1]\xa0Prigozhin also absurdly claimed that over 10 million Americans have applied to join Wagner.[2]\xa0The Wagner Group will likely continue to recruit from prisons, albeit in a much more limited capacity. As ISW has previously noted, Wagner’s recruitment of prisoners has slowed over the last few months, an assessment confirmed by statistics by the Federal Penitentiary Service that show that decreases in the Russian prison population stabilized between November 2022 and January 2023.[3]\xa0This phenomenon is consistent with the overall trend of conventional Russian troops slowly replacing the Wagner Group around Bakhmut, indicating that Russian military command may be shifting away from its reliance on Wagner and therefore on using prisoners as cannon fodder.\n\nThe Kremlin continues to pursue measures to gradually prepare Russia’s defense-industrial base for a protracted war in Ukraine while avoiding wider economic mobilization.\xa0Russian President Vladimir Putin held a meeting with the Supervisory Board of the Agency for Strategic Initiatives on February 9 and instructed the agency to support federal subjects in developing the production of unmanned aircraft systems.[4]\xa0Deputy Chairman of the Russian Security Council Dmitry Medvedev previously stated that Russian military manufacturers intend to expand the supply of reconnaissance and attack drones to support operations in Ukraine, and Russian and Iranian officials are reportedly planning to build a factory in Russia to manufacture 6,000 drones "in the coming years."[5]\n\nMedvedev visited a tank manufacturing plant in Omsk Oblast on February 9 and stated that Russia needs to increase the production of various armaments, including modern tanks, in response to Western military assistance to Ukraine.[6]\xa0Dutch open-source group Oryx reported that Russian forces have lost 1,012 destroyed tanks in Ukraine with an additional 546 tanks captured by Ukrainian forces.[7]\xa0Oryx reported that these combined losses represent roughly half the tanks that Russian forces committed to Ukraine at the start of the invasion.[8]\xa0Fifteen hundred tanks are enough to equip more than 15 tank regiments or brigades or about 150 battalion tactical groups.[9]\xa0The Russian military needs to quickly replenish these tank losses to maintain the ability to conduct large-scale mechanized maneuver warfare ahead of a likely increased pace of offensive operations in eastern Ukraine. Medvedev likely framed his calls for increased production as a response to Western military assistance to obscure the fact that substantial military equipment losses are driving the need for increased production. The Kremlin’s efforts to gradually prepare Russia’s defense industrial base for a protracted war while avoiding a wider mobilization of the Russian economy continue to be incompatible with the scale of the war that the Russian military is fighting in Ukraine and the scale of Russian military equipment losses.\n\nA prominent Wagner-linked  ...

# %%
#4) 폴더내의 파일 읽기



from langchain_community.document_loaders import DirectoryLoader
from langchain_community.document_loaders import TextLoader


loader = DirectoryLoader('./', glob="**/*.txt", show_progress=True, loader_cls=TextLoader)
docs = loader.load()
# Out:
#  80%|███████████████████████████████████████████████████████████████████████████▏                  | 4/5 [00:00<00:00, 7832.50it/s]

# %%
docs[0]
# Out:
# Document(metadata={'source': 'news_data.txt'}, page_content='[속보] 비트코인, 사상 첫 7만4000달러 돌파…이더리움·도지코인도 상승\n추천 기사\n이상현 기자 lee.sanghyun@mkinternet.com\n입력 :  2024-11-06 12:14:18 수정 :  2024-11-06 12:39:50\n가상화폐 대장주 비트코인이 미국 대통령 선거 당일 처음으로 7만4000달러선을 돌파하며 사상 최고가를 경신했다.\n6일(현지시간) 미 가상화폐 거래소 코인베이스에 따르면 미 동부 시간 이날 오후 10시 10분(서부 시간 오후 8시 10분) 비트코인 1개당 가격은 24시간 전보다 8.97% 급등한 7만4033달러를 나타냈다.\n비트코인은 지난 3월 13일 기록했던 7만3800달러대를 뛰어넘으며 이날 사상 처음 7만4000달러대를 돌파했다.\n이날 한때는 7만4900달러대까지 치솟으며 7만5000달러선 돌파도 목전에 뒀다.\n비트코인 가격 급등은 미 대선 개표가 시작된 가운데 장 초반 친(親)가상화폐 행보를 보여온 도널드 트럼프 전 대통령의 당선 가능성에 대한 기대감이 반영된 것으로 보인다.\n같은 시간 시가총액 2위 이더리움은 8.34% 뛰었고, 일론 머스크 테슬라 최고경영자가 띄우는 도지코인은 28% 폭등했다.\n\nAP통신에 따르면 한국시간으로 6일 오후 12시 30분 현재 트럼프 전 대통령은 7개 경합주를 제외한 나머지 선거구에서 198명의 선거인단을 확보해 112명을 기록 중인 해리스 부통령에 앞서 있다.')

# %%
from langchain_community.document_loaders import Docx2txtLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=1500,
    chunk_overlap=200,
)
loader = Docx2txtLoader(file_path="./2021_인투월드_유지보수계약서_수정.docx")
docs = loader.load_and_split(text_splitter=text_splitter)

# %%
docs
# Out:
# [Document(metadata={'source': './2021_인투월드_유지보수계약서_수정.docx'}, page_content='유지보수 용역 계약서\n\n\n\n㈜유베이스 주식회사(이하 “유베이스”라 한다)와 ㈜인투월드테크놀러지(이하 “인투월드”라 한다)는 “유베이스”가 현재 운용하고 있는 “IP-IVR편집기 및 IP_IVR시스템”(이하 “계약제품”이라 하며 제4조 제1호의 대상시설을 의미한다)과 관련하여 “인투월드”가 유지보수(제2조의 정의에 의한다)를 수행함에 있어, 신의성실의 원칙에 입각하여 다음과 같이 기본 유지보수 용역 계약서(이하 “기본계약”이라 한다)를 체결하여 이를 성실히 준수할 것을 약정한다.\n\n\n\n제1조 (목적)\n\n기본 계약은 “인투월드”가 “유베이스”의 계약제품을 유지보수 하는데 필요한 사항과 기타 계약당사자의 권리 및 의무에 관한 제반 사항을 정하여 성실히 이행할 것을 약속함에 목적이 있다.\n\n제2조 (정의)\n\n“유지보수”라 함은 “유베이스”가 “인투월드”에게 위탁한, 계약제품의 성능을 항상 정상 상태로 유지하기 위한 “인투월드”의 제반 관리·문제발생 예방 활동 및 장애 발생시 행하는 보수·정비 용역업무를 말한다.\n\n제3조 (계약의 효력)\n\n기본계약은 체결일 이전에 “유베이스”와 “인투월드” 간에 제2조의 유지보수 용역업무와 동일 혹은 유사한 용역 제공에 대해 체결한 일체의 의향서, 제안서, 양해각서에 우선한다.\n\n기본계약에 대한 계약조건을 변경하고자 할 때는 “유베이스”와 “인투월드”의 합의에 의하되, 쌍방의 서명이 없으면 이를 무효로 한다.\n\n제4조 (유지보수 대상시설 및 용역 범위)\n\n대상시설(계약제품) : IP-IVR 편집기 및 IP-IVR 시스템\n\n유지보수 범위 : “인투월드”가 “유베이스”에게 제공하는 유지보수 업무의 구체적인 범위와 내용은 별첨 1. “용역설명서”에 따른다. 별첨 1. “용역설명서”의 내용은 “유베이스”와 “인투월드”의 서면 합의에 따라 변경될 수 있다.\n\n제5조(계약기간)\n\n기본계약의 유효기간은 2021년 5월 1일부터 2022년 4월 30일까지로 한다. \n\n제6조(유지보수 방법)\n\n“인투월드”는 모든 유지보수를 전문요원에 의하여 수행되도록 하며 계약제품의 정상 가동을 유지하도록 하여야 한다.\n\n계약제품에 대한 “인투월드”의 유지보수 업무 방법은 별첨 1. “용역설명서”에 따른다\n\n제7조 (책임 및 면제)\n\n“인투월드”는 별첨1. “용역설명서”에 기술된 범위와 방법에 따른 서비스를 제공함에 있어 전문가로서 최선의 노력을 다하여 성실히 기본계약을 수행할 것을 보증한다.'),
#  Document(metadata={'source': './2021_인투월드_유지보수계약서_수정.docx'}, page_content='계약제품에 대한 “인투월드”의 유지보수 업무 방법은 별첨 1. “용역설명서”에 따른다\n\n제7조 (책임 및 면제)\n\n“인투월드”는 별첨1. “용역설명서”에 기술된 범위와 방법에 따른 서비스를 제공함에 있어 전문가로서 최선의 노력을 다하여 성실히 기본계약을 수행할 것을 보증한다.\n\n”인투월드”는 천재지변(지진, 홍수, 태풍, 우박 등의 자연재해 내지 기상이변 중 객관적으로 심각한 피해를 입힌 재난 수준의 inclement weather에 준하여야 하며 단순한 bad weather는 포함되지 않음) 또는 불가항력(전쟁, 폭동, 법령의 개폐, 정부의 조치 등을 포함하나 노동쟁의 또는 전염병 등은 포함되지 않음)으로 용역업무를 이행할 수 없는 경우 “유베이스”에게 즉시 통보하여야 하며, 이 경우 “인투월드”는 계약 불이행에 대한 책임이 면제된다. “인투월드”는 천재지변 내지 불가항력 사유가 해소되는 즉시 유지보수를 재개하여 “유베이스”의 손해를 최소화 하기 위해 노력하여야 한다.\n\n제8조 (유지보수 요원의 자격)\n\n“인투월드”는 유지보수를 이행함에 있어 유지보수 요원은 상당한 기술과 경험이 있는 자로 선임하여야 한다.\n\n“유베이스”는 보수요원의 자격검증을 위하여 지원보수요원의 자격 및 경력 증명을 요구할 수 있고, “인투월드”는 이러한 요구에 즉시 응하여야 한다.\n\n“인투월드”가 제출한 보수요원의 자격이 유지보수 대상 물품의 원활한 유지보수에 적합하지 않다고 판단하여 “유베이스”가 유지보수 요원의 교체를 요구한 경우 “인투월드”는 즉시 이에 응하여야 한다.\n\n“인투월드”의 사정으로 인하여 인력을 교체하는 경우, “인투월드”는 교체일 15일 이전에 “유베이스”에게 이를 통보하고 “유베이스”의 동의를 득하여야 한다.\n\n본 조에 의한 교체인력은 기존인력의 기술등급과 동일하거나 그 이상이어야 하며, 이로 인하여 발생하는 추가비용은 “인투월드”가 부담한다.\n\n제9조 (“유베이스”와 “인투월드”의 협력)\n\n“인투월드”는 “유베이스”의 업무수준 측정 요구에 성실히 응하여야 하며, 업무수준 목표에 미달하거나 기타 업무수행에 문제점이 발생하여 “유베이스”가 보완을 요청하는 경우 즉시 필요한 조치를 취하여야 한다. \n\n“인투월드”는 신속한 유지보수를 위하여 항상 작업에 필요한 장비를 사전에 준비하여 완전히 갖추어야 한다. \n\n“유베이스”는 계약제품에 공급되는 전력의 전원 개폐 및 시스템의 조작을 일상적으로 행하는 사람을 지정하고, 그 지정된 사람만이 조작을 행하도록 한다. \n\n“유베이스”는 천재지변 기타 불가항력적 사유(제7조 제2항상의 해당 내용을 준용함)를 제외하고는 계약제품의 설치 환경을 항상 정상적으로 유지시켜야 한다.\n\n계약기간 중 “유베이스”의 사정으로 계약제품을 이전 설치 또는 시설 변경할 경우 “인투월드”는 이전 설치 또는 시설 변경 작업을 수행하여야 하며, 이에 소요되는 비용은 “유베이스”가 부담한다. “인투월드”는 “유베이스”의 요청 시 이전에 소요되는 비용 견적서를 제출하고, 이전 설치에 적극 협조한다.\n\n제10조 (기술제공 및 교육)'),
#  Document(metadata={'source': './2021_인투월드_유지보수계약서_수정.docx'}, page_content='계약기간 중 “유베이스”의 사정으로 계약제품을 이전 설치 또는 시설 변경할 경우 “인투월드”는 이전 설치 또는 시설 변경 작업을 수행하여야 하며, 이에 소요되는 비용은 “유베이스”가 부담한다. “인투월드”는 “유베이스”의 요청 시 이전에 소요되는 비용 견적서를 제출하고, 이전 설치에 적극 협조한다.\n\n제10조 (기술제공 및 교육)\n\n “인투월드”는 다음 각 호의 경우 관련 교재 및 기술자료를 무상으로 “유베이스”에게 제공한다.\n\n가. “인투월드”가 S/W 관련 교재 및 기술자료를 발간한 경우\n\n나. S/W Upgrade 혹은 Version Up 한 경우\n\n다. S/W 변경시 사용 지침서 등\n\n\n\n“유베이스”가 필요에 의하여 “인투월드”에 요청하는 사항에 대하여는 “인투월드”는 자문에 응하여야 한다.\n\n“인투월드”는 “유베이스”의 운용요원 및 “유베이스”가 지정한 자에 대해 필요한 교육을 상호 협의 하에 실시한다.\n\n제11조 (보고서 제출)\n\n“인투월드”는 매월 수행한 유지보수 작업에 대한 내역 작업결과, 점검대장 등을 포함한 ‘유지보수 결과 보고서’(이하 “보고서”라 한다)를 서면으로 작성하여 “유베이스”에게 제출한다.\n\n“유베이스”는 보고서 수령 후, “인투월드”의 실제 유지보수 내역과 보고서 내용이 일치하는지 및 “인투월드”가 유지보수와 관련한 계약 의무 이행을 충실히 하였는지에 대하여 검사한 후 “인투월드”에게 그 결과를 통보하여야 한다.\n\n제12조 (유지보수료 및 대금의 지급)\n\n계약기간 동안 유지보수료의 총계는 일금 칠천사백삼십팔만오천원(₩74,385,000/부가세별도)이며 IVR별 금액은 별첨 2. “유지보수 견적서”에 따른다.\n\n“인투월드”는 유지보수료에 대하여 매 해당월 말일까지 세금계산서 발행을 통해 “유베이스”에게 청구하며, “유베이스”는 세금계산서 발행일의 익월 25일에 현금으로 지급한다.\n\n“유베이스”의 “인투월드”에 대한 대금 지급은 “인투월드”의 완전한 유지보수 수행을 전제로 한다. 따라서 기본 계약에서 정한 용역 범위에 해당하는 “유베이스”의 요청사항을 “인투월드”가 이행하지 않은 경우 대금의 전부 또는 일부의 지급을 보류할 수 있다. 단, “인투월드”에게 “유베이스”의 요청을 이행하기 곤란한 정당한 사유가 있어 사전에 “유베이스”의 서면 승인을 받은 경우에 한하여 예외로 한다.\n\n제13조 (지체상금)\n\n정비시설 재정비 지연 : ”인투월드”는 정비불량 사항에 대한 “유베이스”의 재정비 등 조치요구에 대하여 재정비 요구가 있은 때로부터 정당한 사유 없이 24 시간 이상 지체할 경우, 24시간 경과 후 매 1일에 대하여 총 계약대금(유지보수료 총계를 의미하며 이하 본 조에서 동일함)의 1000분의 3에 해당하는 지체상금을 “유베이스”에게 지불한다. “유베이스”가 지체상금을 “인투월드”에게 지급할 유지보수료와 상계할 수 있다.'),
#  Document(metadata={'source': './2021_인투월드_유지보수계약서_수정.docx'}, page_content='복구 지연 : “인투월드”는 기본계약상 시스템의 고장으로 인하여 요구된 정비를 함에 있어 별첨 1. “용역설명서”에 의한 정상복구 시간을 초과할 경우, 초과한 기간 매 1일에 대하여 총 계약대금의 1000분의 3에 해당하는 지체상금을 “유베이스”에게 지불한다. “유베이스”는 지체상금을 “인투월드”에게 지급할 유지보수료와 상계할 수 있다.\n\n베이스”가 지체상금을 유지보수료에서 상계하여 지급하는 경우, “유베이스”가 “인투월드”에게 상계 금액을 서면으로 통보하고 “인투월드”는 유지보수료 청구 시 상계 금액만큼 감액 청구하여 정산한다.\n\n제14조 (권리의무의 양도 금지)\n\n당사자는 서면에 의한 상대방의 사전 서면 승낙 없이 기본계약에 의한 어떠한 권리, 의무의 전부 또는 일부를 제3자에게 양도, 담보제공, 기타 어떠한 처분행위를 할 수 없다.\n\n”유베이스”가 업무의 신속성 및 효율성을 위하여 필요하다고 인정할 경우 “인투월드”는 운용 및 유지보수 자격을 갖춘 제3자에게 기본계약상 용역을 위임 또는 하도급을 줄 수 있으며, 이 경우에도 “인투월드”는 반드시 “유베이스”의 사전 서면 동의를 득하여야 한다.\n\n전항의 규정에 의하여 위임 또는 하도급을 받은 제3자는 “유베이스”와 “인투월드”가 체결한 기본계약의 계약규정을 준수하여야 하고, “인투월드”와 동일하게 기본 계약을 이행하여야 한다.\n\n제15조 (하자보증)\n\n “인투월드”는 “인투월드”가 “유베이스”에게 제공한 유지보수에 대하여 일체의 하자가 없음을 보증한다.\n\n“인투월드”가 “유베이스”에게 제공한 유지보수에서 하자가 발견 또는 발생되었을 경우에는 “인투월드”는 자신의 책임과 부담으로 지체 없이 하자를 수리하여 “유베이스”의 업무에 차질이 생기지 않도록 조치하여야 한다. 만약 수리로써 하자 치유가 불가할 경우 “인투월드”는 감가상각 분을 제한 계약제품과 동일 품질의 제품으로 교체하는 데 필요한 비용 등 계약제품에 발생한 하자로 인하여 “유베이스”가 입은 모든 손해 및 손실에 대하여 배상 및 보상하여야 한다.\n\n무상하자보수 기간은 제11조에 따른 각 보고서상 검사 완료일로부터 1년으로 한다.\n\n제16조 (계약의 해제 또는 해지)\n\n유베이스” 또는 “인투월드”는 어느 일방에 대해 다음 각 호의 사유가 발생했을 경우 상대방에게 서면 통보 후 기본계약의 전부 또는 일부를 즉시 해제 또는 해지할 수 있다.\n\n가. 어음 또는 수표의 부도가 발생했을 때 또는 금융기관으로부터 거래정지처분을 받았을 경우\n\n나. 감독 관청으로부터 영업취소, 정지 등의 처분을 받았을 경우\n\n다. 제3자로부터 압류, 가압류, 가처분, 강제집행 등을 받아 계약 이행이 곤란하다고 판단되는 경우\n\n라. 파산 또는 채무자회생 절차를 법원에 신청하거나 개시결정/파산선고가 난 경우\n\n마. 관련법을 위반한 경우\n\n바. “유베이스”의 사유로 인하여 본 계약을 해지하여야 하고자 하는 경우. 단, 이 경우 30일의 사전 통보를 하여야 한다.'),
#  Document(metadata={'source': './2021_인투월드_유지보수계약서_수정.docx'}, page_content='다. 제3자로부터 압류, 가압류, 가처분, 강제집행 등을 받아 계약 이행이 곤란하다고 판단되는 경우\n\n라. 파산 또는 채무자회생 절차를 법원에 신청하거나 개시결정/파산선고가 난 경우\n\n마. 관련법을 위반한 경우\n\n바. “유베이스”의 사유로 인하여 본 계약을 해지하여야 하고자 하는 경우. 단, 이 경우 30일의 사전 통보를 하여야 한다.\n\n“유베이스” 또는 “인투월드”는 다음 각 호의 사유가 발생하였을 때에는 서면으로 시정 또는 계약 이행을 통보하고, 그로부터 15일이 경과하여도 시정 또는 계약이 이행되지 않을 때에는 기본계약의 일부 또는 전부를 해제 또는 해지할 수 있다.\n\n가. “유베이스” 또는 “인투월드”가 계약사항을 위반하였을 경우 또는 기타 계약의 목적을 달성하기 어렵다고 객관적으로 판단되는 경우\n\n나. “인투월드”가 계약기간 중 별첨 1.”용역설명서” 상 정상복구 기한을 특별한 사유 없이 2회 이상 초과하여 계속적 거래가 곤란하다고 판단될 경우\n\n다. “인투월드”가 계약기간 중 별첨 1.”용역설명서” 상 “유베이스”의 유지보수 요청에 대하여 특별한 사유 없이 2회 이상 약정 착수기한을 초과하여 계속적 거래가 곤란하다고 판단될 경우\n\n라. “인투월드”가 나.호와 다.호 외에 계약제품의 유지보수에 필요한 사항의 이행을 특별한 사유 없이 지연함으로써 “유베이스”의 업무에 지장을 초래하게 할 경우\n\n제17조 (손해배상)\n\n기본계약과 관련하여 “인투월드”의 고의 또는 과실로 인하여 “유베이스”가 손해를 입은 경우, “인투월드”는 이를 배상할 책임이 있다. 다만, 천재지변, 기타 불가항력적 사유(제7조 제2항상의 해당 내용을 준용함)로 인한 경우에는 예외로 한다.\n\n제14조에 의거 “인투월드”로부터 위임 또는 하도급을 받은 제3자의 귀책으로 인하여 “유베이스”에 손해가 발생한 경우 “인투월드”는 해당 제3자와 연대하여 그 손해를 완전히 배상하고 유베이스를 면책시킬 책임을 부담한다.\n\n\n\n제18조 (비밀준수의무)\n\n양 당사자는 기본계약과 관련하여 상대방으로부터 제공받거나, 업무상 알게 된 기술정보, 거래내용 등 영업비밀에 대하여 계약기간 또는 계약의 종료 후에도 제3자에게 누설하거나 다른 목적에 사용할 수 없다.\n\n“인투월드”는 기본 계약이 해제/해지 기타 종료된 경우 “유베이스”로부터 제공받은 비밀정보에 관한 자료를 “유베이스”에게 즉시 반환하거나 “유베이스”의 확인 하에 폐기하여야 한다.\n\n제19조 (개인정보보호 관련 법 준수 의무)\n\n“인투월드”는 “유베이스”와 기본계약을 체결하여 유지보수를 수행하면서 개인정보보호법, 정보통신망이용촉진 및 정보보호 등에 관한 법률 등 개인정보보호와 관련된 법령 및 제반규정을 엄격히 준수하여야 한다.\n\n“인투월드”가 “유베이스”의 사면 동의를 얻어 제3자에게 위임 또는 하도급을 주었을 경우, 그 제3자도 반드시 개인정보보호 관련 법령 및 제반규정을 준수하여야 하며, “인투월드”는 제3자가 법을 준수할 수 있도록 책임지고 지도하고 관리하여야 한다.'),
#  Document(metadata={'source': './2021_인투월드_유지보수계약서_수정.docx'}, page_content='“인투월드”가 “유베이스”의 사면 동의를 얻어 제3자에게 위임 또는 하도급을 주었을 경우, 그 제3자도 반드시 개인정보보호 관련 법령 및 제반규정을 준수하여야 하며, “인투월드”는 제3자가 법을 준수할 수 있도록 책임지고 지도하고 관리하여야 한다. \n\n“인투월드” 및 “인투월드”에게 위임 또는 하도급을 받은 제3자는 본 조를 위반함으로 인하여 “유베이스”에게 발생하는 모든 손해를 연대하여 배상하여야 하며, 이에 대하여 “인투월드”는 민형사, 행정상 모든 책임에서 “유베이스”를 면책하여야 한다.\n\n제20조 (분쟁 및 합의관할)\n\n기본계약의 해석에 관하여 이견이 있을 때에는 “유베이스”와 “인투월드”가 상호 협의하여 결정하며, 상호 협의에 의하여 해결되지 않을 경우 관련 법령 및 상관례에 따른다. 분쟁 발생시에는 인천지방법원 부천지원을 전속적 합의관할법원으로 하여 소송으로 해결한다.\n\n제21조 (기타)\n\n기본계약을 기초로 하여 이미 발생한 “유베이스”와 “인투월드”간의 권리의무는 기본계약의 종료에 의하여 영향을 받지 않는다.\n\n\n\n[별첨]\n\n1. 용역설명서\n\n2. 유지보수 견적서\n\n\n\n위와 같이 계약하며, 기본계약이 유효하게 성립되었음을 증명하기 위하여 “유베이스”와 “인투월드”가 각 기명 날인한 후 각각 1부씩 보관한다.\n\n\n\n2021년 00월 00일\n\n\n\n“유베이스”\n\n㈜유베이스\n\n\n\n서울 용산구 한강대로 38길 37\n\n(용산동5가)\n\n\n\n대표이사   허대건     (인)\n\n“인투월드”\n\n㈜인투월드 테크놀러지\n\n\n\n경기 성남시 분당구 대왕판교로 645번길 12 4층 c05\n\n\n\n대표이사   권 무 혁     (인)\n\n\n\n\n\n\n\n\n[첨부1] 용역설명서\n\n\n\n\n\n\n\n용역설명서\n\n(IVR 편집기 및 IVR 유지보수)\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n2020. 00. 00\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n1. 용역개요: IPIVR편집기 및 IPIVR 시스템 유지보수\n\n2. 용역기간: 2020년 05월 01일 ~ 2021년 4월 31일\n\n3. 용역내용\n\n① 일반사항\n\n정기 점검\n\n- (시스템 체크) 접속하여 시스템의 가용용량과 비정상 이벤트를 체크하여, 담당자에게 정상여부를 리포트하고, 수정대응을 요청한다.\n\n- (서비스 체크) 솔루션자체와 연관된 데몬의 정상 동작 여부와, 로그를 분석하여, 담당자에게 정상여부를 리포트\n\n기술 문의 요청 대응\n\n- 시스템과 서비스에 관한 운영 및 업그레이드 등에 관한 기술적 문의에 대한 답변(이메일과 전화, 톡)\n\nIP-IVR 시스템 기술 지원 \n\n시나리오와 관련한 TCP 연동에 관련하여 개발 및 업그레이드를 지원한다. 단, 난이도가 높거나, 공수가 많이 들어갈 경우에는 별도 계약으로 한다.\n\n② 긴급장애사항: 손망실이 안된 상태에서, 환경변화가 없는 상태에서, 사용 중에 발생한 장애에 해당\n\n- (네트워크장애) 네트워크나 방화벽같은 문제로 장애 발생시 \n\n- (시스템장애) 서버의 물리적인 상태는 정상이나, OS와 데몬, 패키지들의 비정상 동작\n\n- (전화장애) IVR과 PBX과의 연결에 장애 발생'),
#  Document(metadata={'source': './2021_인투월드_유지보수계약서_수정.docx'}, page_content='② 긴급장애사항: 손망실이 안된 상태에서, 환경변화가 없는 상태에서, 사용 중에 발생한 장애에 해당\n\n- (네트워크장애) 네트워크나 방화벽같은 문제로 장애 발생시 \n\n- (시스템장애) 서버의 물리적인 상태는 정상이나, OS와 데몬, 패키지들의 비정상 동작\n\n- (전화장애) IVR과 PBX과의 연결에 장애 발생\n\n- (재설치) OS의 재설치, 패키지의 재설치, 폰웹솔루션의 재설치는 ⑥과 ⑦ 해당\n\n③하자지원\n\n- 계약제품에서 버그가 발견되면, 무상으로 지원한다.\n\n계약제품의 자체 업그레이드\n\n- 기능 및 심각한 버그를 개선한 계약제품 자체의 업그레이드가 발생하면, 고객사와 협의 하에 무상 지원한다.\n\n- 고객사는 이에 적극 협조해야 한다.\n\n기능 수정 및 업그레이드\n\n- (유상)요청한 사항을 해결하는데, 투입 시간이 많이 걸리거나, 기술적 난이도가 높을 경우에는 유상 견적으로 진행\n\n- (무상)유상의 조건에 해당하지 않는 경우에는 협의 하에 지원\n\n네트워크, 시스템 환경 변경 및 교체\n\n- 사전에 통보없이 기존 설치환경에서 변경이 있을 경우에는, 예상 투입 인력을 고려한 유상\n\n- 시스템 교체로 인한 재설치는 무상지원, 단, OS및 사용환경이 기존 것과 동일 조건이 아닐 경우에는 유상\n\n손망실\n\n- 인위적으로 고의적이고, 사전에 인지된 상황, 관리 소홀로 발생한 손망실은 유상 지원(정상 견적가)\n\n- 천재지변 및 예측불가로 인한 손망실에 대해서, 제공한 계약제품은 무상지원\n\n대응 및 처리 방법과 시간\n\n- (원격접속) 원격접속으로 시스템에 직접 접속하여 상기 내용을 지원, 고객사가 원격접속 도구를 제공하고, 관리자권한을 제공한다.\n\n- (현장방문) 시스템의 교체에 따른, 재설치 경우에 해당 시스템 업체 및 현장 방문하여 지원\n\n- (하자 및 기능보완의 소요시간) 기술적 난이도를 고려한 예상 소요시간을 기초로 진행하고, 진행상황을 공유하여 진행 방법과 시간을 협의하여 결정(발생시점부터 24시간 내)\n\n- (정기점검) 월 1회, 상호 협의한 시간에 진행하고, 1주내로 해당 결과 리포트를 전송한다.\n\n- (리포트서식) 리포트는 사전 협의된 서식으로 파일 형태를 사용\n\n- (기술문의) 분기 3회, 단순 문의일 경우에 해당하고, 난이도가 높은 경우에는 상호 협의 하에 유상\n\n소유권 및 사용권 이전\n\n- 계약제품의 사용권 또는 계약제품의 점유가 타사로 이전될 경우에는 본 계약은 잔여 계약기간의 존부와 무관하게즉시 종료한다.\n\n\n\n\n\n\n\n\n\n\n[첨부2] 견적서')]
